# %%
print("Merhaba, İGÜ - İSTKA/ Ders 2")
import sys
print(sys.version)
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/veriyapilari_colaboratory')
# !pwd
# Out:
# Merhaba, İGÜ - İSTKA/ Ders 2
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/veriyapilari_colaboratory

# %%
#Geçerli değişken tanımlaması
degisken_1=10
Degisken=20
_degisken3=30

# %%
#Geçersiz degişken tanımlaması
1degisken = 40
degisken-4 = 50
# Out:
#   File "<ipython-input-5-d0fcaaf8a3f1>", line 2
#     1degisken = 40
#     ^
# SyntaxError: invalid decimal literal

# %%
# Degişken Tanımlama İşlemi
x = 5
y = "Merhaba Dünya"

print(x)
print(y)
# Out:
# 5
# Merhaba Dünya

# %%
#Integer - Tam sayı tanımlaması

a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
#Float -Ondalıklı Sayı tanımlaması
b = 20.5
print(type(b))
# Out:
# <class 'float'>

# %%
# Int'ten float'a çevrimin gerçekleştirilmesi
x = 10
y = float(x)
print(y, type(y))
# Out:
# 10.0 <class 'float'>

# %%
#float'dan int'e çevriminin gerçekleştirilmesi
a = 12.34
b= int(a)
print(b, type(b))
# Out:
# 12 <class 'int'>

# %%
#String -Metinsel içerik tanımlaması
c="Phyton Programlama"
print(c)
print(type(c))
# Out:
# Phyton Programlama
# <class 'str'>

# %%
# Boolean (True -False) - Doğru /Yanlış tanımlaması
d = True
e = False
print(d)
print(type(e))
# Out:
# True
# <class 'bool'>

# %%
#List -Liste tanımlaması
liste = [1, 2, 3, 4, 5]
print(type(liste))
print(liste)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5]

# %%
# Tuple -Demet tanımlaması

demet = (1, 2, 3, 4, 5)
print(type(demet))
print(demet)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5)

# %%
#Dictionary-Sözlük Örneği-<Öğrencilerin not ortalaması
notlar = {
    "Ali": 85,
    "Veli": 90,
    "Ayşe": 78
}
notlar ["Fatma"] =92 # Yeni öğrenci ekleme
notlar ["Ali"] =88 # Bir öğrencinin notunu güncelleme

print(notlar)


print(notlar.keys()) #dic_keys(['isim','yas', 'meslek'])
print(notlar.values()) #dict_values(['Ahmet','26','Mühendis'])
print(notlar.items()) #dict_items([('isim','Ahmet'), ('yas',26),('meslek','Muhendis')])print(notlar.keys()) #dic_keys(['isim','yas', 'meslek'])
# Out:
# {'Ali': 88, 'Veli': 90, 'Ayşe': 78, 'Fatma': 92}
# dict_keys(['Ali', 'Veli', 'Ayşe', 'Fatma'])
# dict_values([88, 90, 78, 92])
# dict_items([('Ali', 88), ('Veli', 90), ('Ayşe', 78), ('Fatma', 92)])

# %%
#Set -Küme Örneği ->Bir yazılım etkinliğine katılan kişilerin oluşturduğu kümeler
kodyazanlar = {"Ahmet", "Mehmet", "Ayşe"}
kodyazmayanlar = {"Ayşe", "Fatma","Veli"}
#Kafasına göre takılan öğrenciler
ortak= kodyazanlar.intersection(kodyazmayanlar)
print("Kafasına göre takılan öğrencilerin listesi:",ortak)

#Etkinlikte kod çalışması yapmayan öğrencilerin tespiti
Kod_yazmayan = kodyazmayanlar.difference(kodyazanlar)# difference(): ikinci kümeye ait olup birinci kümede bulunmayan elemanlar döndürülür.
print("Kod  yazmayan öğrenciler", Kod_yazmayan)
#Yazılım Eğitiminin Öğrenci İmza Listesi
imza_listesi = kodyazanlar.union(kodyazmayanlar)#union(): Her iki kümedeki tüm öğeleri içeren yeni bir küme döndürür.
print("Etkinlik Katılımcıları:", imza_listesi)
# Out:
# Kafasına göre takılan öğrencilerin listesi: {'Ayşe'}
# Kod  yazmayan öğrenciler {'Fatma', 'Veli'}
# Etkinlik Katılımcıları: {'Ayşe', 'Fatma', 'Mehmet', 'Ahmet', 'Veli'}

# %%
giris = input("Bir sayı girin:")
try:
  num = float(giris)
  print(f"Girilen sayı: {num}, tipi: {type(num)}, ", abs(num))
except valueError:
  print("Gecersiz veri girdiniz.")
# Out:
# Bir sayı girin:5
# Girilen sayı: 5.0, tipi: <class 'float'>,  5.0

# %%
# 0 ile 1 arasında rastgele bir ondalık sayı üretir

import random

rastgele_float = random.random()
print("Rastgele Deger:", rastgele_float)
# Out:
# Rastgele Deger: 0.8607087361673457

# %%
#1 ile 10 arasında (her iki sınır dahil) raastgele bir tam sayı üretir

import random

rastgele_sayi = random.randint(1,10)
print("Rastgele Deger:", rastgele_float)
# Out:
# Rastgele Deger: 0.8607087361673457
